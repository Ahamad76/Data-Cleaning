# %% [markdown]
# # Data Analysis with Python, Numpy, and pandas using Jupyter Notebook

# %%
# Import the required libraries 
import pandas as pd

# %%
import numpy as np

# %%
# Read csv file into a pandas dataframe which is a 2 dimensional spreadsheet-like data structure 
df=pd.read_csv("/Volumes/E/dataset/diabetes_data_upload.csv")

# %%
# the first few rows or we can see the last few rows with tail(n)
df.head(5)
# Out:
#    Age Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0   40   Male       No        Yes                 No      Yes         No
# 1   58   Male       No         No                 No      Yes         No
# 2   41   Male      Yes         No                 No      Yes        Yes
# 3   45   Male       No         No                Yes      Yes        Yes
# 4   60   Male      Yes        Yes                Yes      Yes        Yes
#
#   Genital thrush visual blurring Itching Irritability delayed healing  \
# 0             No              No     Yes           No             Yes
# 1             No             Yes      No           No              No
# 2             No              No     Yes           No             Yes
# 3            Yes              No     Yes           No             Yes
# 4             No             Yes     Yes          Yes             Yes
#
#   partial paresis muscle stiffness Alopecia Obesity     class
# ...

# %% [markdown]
# # Some Basic Analysis of given Dataset

# %%
# find the size(No of rows and column) of dataset
df.shape
# Out:
# (520, 17)

# %%
#find some statistics about the numerical data columns in a dataset
df.describe(include='all')
# Out:
#                Age Gender Polyuria Polydipsia sudden weight loss weakness  \
# count   520.000000    520      520        520                520      520
# unique         NaN      2        2          2                  2        2
# top            NaN   Male       No         No                 No      Yes
# freq           NaN    328      262        287                303      305
# mean     48.028846    NaN      NaN        NaN                NaN      NaN
# std      12.151466    NaN      NaN        NaN                NaN      NaN
# min      16.000000    NaN      NaN        NaN                NaN      NaN
# 25%      39.000000    NaN      NaN        NaN                NaN      NaN
# 50%      47.500000    NaN      NaN        NaN                NaN      NaN
# 75%      57.000000    NaN      NaN        NaN                NaN      NaN
# max      90.000000    NaN      NaN        NaN                NaN      NaN
#
#        Polyphagia Genital thrush visual blurring Itching Irritability  \
# ...

# %%
# We can find other parameteres like mean, median, mode, count, etc for a particular column  as follows:
df.mean(axis=0)
# Out:
# Age    48.028846
# dtype: float64

# %%
df.Gender.count()
# Out:
# 520

# %%
# Find the types of data column (Features's type)
df.dtypes
# Out:
# Age                    int64
# Gender                object
# Polyuria              object
# Polydipsia            object
# sudden weight loss    object
# weakness              object
# Polyphagia            object
# Genital thrush        object
# visual blurring       object
# Itching               object
# Irritability          object
# delayed healing       object
# partial paresis       object
# muscle stiffness      object
# Alopecia              object
# Obesity               object
# class                 object
# dtype: object

# %% [markdown]
# # Transform the data

# %%
#
df['gender_map']=df.Gender.apply(lambda y: 1 if y == "Male"  else  0)

# %%
df.head(10)
# Out:
#    Age Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0   40   Male       No        Yes                 No      Yes         No
# 1   58   Male       No         No                 No      Yes         No
# 2   41   Male      Yes         No                 No      Yes        Yes
# 3   45   Male       No         No                Yes      Yes        Yes
# 4   60   Male      Yes        Yes                Yes      Yes        Yes
# 5   55   Male      Yes        Yes                 No      Yes        Yes
# 6   57   Male      Yes        Yes                 No      Yes        Yes
# 7   66   Male      Yes        Yes                Yes      Yes         No
# 8   67   Male      Yes        Yes                 No      Yes        Yes
# 9   70   Male       No        Yes                Yes      Yes        Yes
#
#   Genital thrush visual blurring Itching Irritability delayed healing  \
# 0             No              No     Yes           No             Yes
# ...

# %%
df.gender_map.value_counts()
# Out:
# 1    328
# 0    192
# Name: gender_map, dtype: int64

# %%
# to drop some columns from dataset
drop_columns=['Gender','Polyuria']
df.drop(drop_columns, inplace=True, axis=1)
df.head(5)
# Out:
#    Age Polydipsia sudden weight loss weakness Polyphagia Genital thrush  \
# 0   40        Yes                 No      Yes         No             No
# 1   58         No                 No      Yes         No             No
# 2   41         No                 No      Yes        Yes             No
# 3   45         No                Yes      Yes        Yes            Yes
# 4   60        Yes                Yes      Yes        Yes             No
#
#   visual blurring Itching Irritability delayed healing partial paresis  \
# 0              No     Yes           No             Yes              No
# 1             Yes      No           No              No             Yes
# 2              No     Yes           No             Yes              No
# 3              No     Yes           No             Yes              No
# 4             Yes     Yes          Yes             Yes             Yes
#
#   muscle stiffness Alopecia Obesity     class
# 0              Yes      Yes     Yes  Positive
# ...
